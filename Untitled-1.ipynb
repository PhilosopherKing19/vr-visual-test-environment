# %%
import sympy
a=0#a=31

# %%
def bit_flip(x):
    return x ^ ((1 << x.bit_length()) - 1)
lengths=list()
results = list()
falseResults=list()
trueResults=list()

# %%
l=list(sympy.primerange(2**a,2**(a+1)))
b= list()
lengths.append(len(l))
#print(l)
for n in l:
 
 b.append(bit_flip(n))
results.append(sum(b)+1)
a=a+1

print(results[-1])
prevs=list()
nexts=list()




#print(lengths)
print(a)
# Out:
# 27364233922636413
# 31

# %%
if sympy.isprime(results[-1]) != True:
    falseResults.append(results[-1])
else: trueResults.append(results[-1])
#prevs.append(sympy.prevprime(n))
nexts.append(sympy.nextprime(n))
print(prevs)
print(falseResults)
print(nexts)
print(lengths)
print(trueResults)
# Out:
# []
# [1, 1505, 19085, 263311, 962075, 3609977, 13348283, 50339727, 188978735, 2695143989, 10212322985, 38890573919, 148257654379, 566593623823, 2169832548613, 8324544731069, 31979410967449, 123090717697551, 474405837431259, 1830735442486153, 7074006596250749, 27364233922636413]
# [2147483659]
# [0, 2, 2, 2, 5, 7, 13, 23, 43, 75, 137, 255, 464, 872, 1612, 3030, 5709, 10749, 20390, 38635, 73586, 140336, 268216, 513708, 985818, 1894120, 3645744, 7027290, 13561907, 26207278, 50697537]
# [2, 3, 7, 37, 101, 433, 5507, 71453, 711552757]

# %%
for i in range(len(falseResults)):
    print(falseResults[i]-prevs[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[173], line 2
#       1 for i in range(len(falseResults)):
# ----> 2     print(falseResults[i]-prevs[i])
#
# IndexError: list index out of range

# %%
for i in range(len(falseResults)):
    print(nexts[i] - falseResults[i])
# Out:
# 6
# 2
# 12
# 2
# 20
# 44
# 14
# 2

# %%
import sympy

print(sympy.isprime(432+7))
print(sympy.isprime(1504+7))
print(sympy.isprime(5506-3))
print(sympy.isprime(19084+3))
print(sympy.isprime(71452+19))
print(sympy.isprime(263310-7))
print(sympy.isprime(962074-11))
print(sympy.isprime(3609976-3))
print(sympy.isprime(13348282-5))
print(sympy.isprime(188978734-11))
print(sympy.isprime(2695143988-29))
print(sympy.prevprime(2695143989))
print(sympy.nextprime(2695143989))
print(sympy.isprime(439))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# 2695143959
# 2695144009
# True
